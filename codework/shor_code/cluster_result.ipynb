# %%
include("functions.jl")

using Pkg
Pkg.precompile()

using Plots, JLD2, LaTeXStrings, FileIO

# %% [markdown]
# ### Result for 9 atoms

# %%
@load "/home/agfleischhauer/roq68sum/master_work/shor_code_data/trial/N_atoms=9_γ_decay=0.001_Ntraj=1.jld2"

population_data = population_data;

@load "/home/agfleischhauer/roq68sum/master_work/shor_code_data/trial/N_atoms=9_γ_decay=0.001_Ntraj=2.jld2"
population_data2 = population_data;

# %%
plot(population_data2[:a], label="atom a", xlabel="time steps", ylabel="population probability", title="Population dynamics")
plot!(population_data2[:c], label="atom c")

# %%
plot(population_data2[:a], label="atom a", xlabel="time steps", ylabel="population probability", title="Population dynamics")
plot!(population_data2[:c], label="atom c")
plot!(population_data2[:p1], ylim=[0,1], label="atom 1", xlabel="time steps", ylabel="population probability", title="Population dynamics")
plot!(population_data2[:p2], label="atom 2")
plot!(population_data2[:p3], label="atom 3")
plot!(population_data2[:p4], label="atom 4")
plot!(population_data2[:p5], label="atom 5")
plot!(population_data2[:p6], label="atom 6")

# %% [markdown]
# ### Shor code debug

# %%
for t in 1:T3
    println(coeff3[1](t)[7])
end
# Out:
# BoundsError: attempt to access 6-element Vector{Float64} at index [7]
#
#
#
# Stacktrace:
#
#  [1] throw_boundserror(A::Vector{Float64}, I::Tuple{Int64})
#
#    @ Base ./essentials.jl:14
#
#  [2] getindex
#
#    @ ./essentials.jl:916 [inlined]
#
#  [3] top-level scope
#
#    @ ~/master_work/rydberg_qec/codework/shor_code/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W6sZmlsZQ==.jl:2

# %%
H3.factors
# Out:
# 6-element Vector{ComplexF64}:
#      0.5 + 0.0im
#      0.5 + 0.0im
#   1032.0 + 0.0im
#   1032.0 + 0.0im
#  -1000.0 + 0.0im
#  -1000.0 + 0.0im

# %%
function Ht(t)
    if t<T1 || t==T1
        coeffs = coeff1[1](t)
        for i in eachindex(coeffs)
            H1.factors[i] = coeffs[i]
        end
        # return H1

    elseif t<(T1+T2) || t==(T1+T2)
        coeffs = coeff2[1](t-T1)
        for i in eachindex(coeffs)
            H2.factors[i] = coeffs[i]
        end
        # return H2

    elseif t<(T1+T2+T3) || t==(T1+T2+T3)
        coeffs = coeff3[1](t-T1-T2)
        for i in eachindex(coeffs)
            H3.factors[i] = coeffs[i]
        end
        return H3.factors[7]
    end
end

for t in tspan
    println(Ht(t))
end
# Out:
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# ...
