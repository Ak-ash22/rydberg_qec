# %%
include("functions.jl")

using Pkg
Pkg.precompile()

using Plots, JLD2, LaTeXStrings, FileIO
# Out:
# Precompiling project...
# ┌ Warning: attempting to remove probably stale pidfile
# │   path = /amd/home/agfleischhauer/roq68sum/.julia/compiled/v1.11/SimpleBufferStream/QbHsM_Y651M.ji.pidfile
# └ @ FileWatching.Pidfile /amd/home/agfleischhauer/roq68sum/.julia/juliaup/julia-1.11.3+0.x64.linux.gnu/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:249
#    2917.2 ms  ✓ LaTeXStrings
#    2010.8 ms  ✓ CommonEq
#    2001.5 ms  ✓ TensorCore
#    1985.4 ms  ✓ StableRNGs
#    2941.0 ms  ✓ Libffi_jll
#    2930.9 ms  ✓ Wayland_protocols_jll
#    3015.0 ms  ✓ OpenSSL_jll
#    3006.0 ms  ✓ Xorg_libICE_jll
#    2921.4 ms  ✓ Libuuid_jll
#    2818.8 ms  ✓ Ogg_jll
#    2769.6 ms  ✓ x265_jll
#    2748.0 ms  ✓ x264_jll
#    2798.5 ms  ✓ mtdev_jll
#    2724.3 ms  ✓ Libiconv_jll
#    2276.0 ms  ✓ SimpleBufferStream
#    1215.0 ms  ✓ EpollShim_jll
#    2606.1 ms  ✓ Graphite2_jll
#    5544.7 ms  ✓ FixedPointNumbers
#    2702.6 ms  ✓ Xorg_libXau_jll
#    2680.2 ms  ✓ Pixman_jll
# ...

# %% [markdown]
# ### Result for 9 atoms

# %%
@load "/home/agfleischhauer/roq68sum/master_work/shor_code_data/trial/N_atoms=9_γ_decay=0.001_Ntraj=1.jld2"

population_data = population_data;

# %%
plot(population_data[:a], label="atom a", xlabel="time steps", ylabel="population probability", title="Population dynamics")
plot!(population_data[:c], label="atom c")

# %%
plot(population_data[:p1], label="atom 1", xlabel="time steps", ylabel="population probability", title="Population dynamics")
plot!(population_data[:p2], label="atom 2")
plot!(population_data[:p3], label="atom 3")
plot!(population_data[:p4], label="atom 4")
plot!(population_data[:p5], label="atom 5")
plot!(population_data[:p6], label="atom 6")

# %% [markdown]
# ### Shor code debug

# %%
for t in 1:T3
    println(coeff3[1](t)[7])
end
# Out:
# 1031.583
# 1031.166
# 1030.749
# 1030.332
# 1029.915
# 1029.498
# 1029.081
# 1028.664
# 1028.247
# 1027.83
# 1027.413
# 1026.996
# 1026.579
# 1026.162
# 1025.745
# 1025.328
# 1024.911
# 1024.494
# 1024.077
# 1023.66
# 1023.243
# 1022.826
# 1022.409
# 1021.992
# 1021.575
# 1021.158
# 1020.741
# 1020.324
# 1019.907
# 1019.49
# 1019.073
# 1018.656
# 1018.239
# 1017.822
# 1017.405
# 1016.988
# 1016.571
# 1016.154
# 1015.737
# 1015.32
# 1014.903
# 1014.486
# 1014.069
# 1013.652
# 1013.235
# 1012.818
# 1012.401
# 1011.984
# 1011.567
# 1011.15
# 1010.733
# 1010.316
# 1009.899
# 1009.482
# 1009.065
# 1008.648
# 1008.231
# 1007.814
# 1007.397
# 1006.98
# 1006.563
# 1006.146
# 1005.729
# 1005.312
# 1004.895
# 1004.478
# 1004.061
# 1003.644
# 1003.227
# 1002.81
# 1002.393
# 1001.976
# 1001.559
# 1001.142
# 1000.725
# 1000.308
# 999.891
# 999.474
# 999.057
# 998.64
# 998.223
# 997.806
# 997.389
# 996.972
# 996.555
# 996.138
# 995.721
# 995.304
# 994.887
# 994.47
# 994.053
# 993.636
# 993.219
# ...

# %%
H3.factors
# Out:
# 6-element Vector{ComplexF64}:
#                 0.5 + 0.0im
#                 0.5 + 0.0im
#  1031.9878220682735 + 0.0im
#  1031.9878220682735 + 0.0im
#             -1000.0 + 0.0im
#             -1000.0 + 0.0im

# %%
function Ht(t)
    if t<T1 || t==T1
        coeffs = coeff1[1](t)
        for i in eachindex(coeffs)
            H1.factors[i] = coeffs[i]
        end
        # return H1

    elseif t<(T1+T2) || t==(T1+T2)
        coeffs = coeff2[1](t-T1)
        for i in eachindex(coeffs)
            H2.factors[i] = coeffs[i]
        end
        # return H2

    elseif t<(T1+T2+T3) || t==(T1+T2+T3)
        coeffs = coeff3[1](t-T1-T2)
        for i in eachindex(coeffs)
            H3.factors[i] = coeffs[i]
        end
        return H3.factors[7]
    end
end

for t in tspan
    println(Ht(t))
end
# Out:
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# ...
